# %% [markdown]
# <a href="https://colab.research.google.com/github/sungrae98/Machine-Learning/blob/main/03_%EB%8D%B0%EC%9D%B4%ED%84%B0_%EB%B6%84%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random

random.seed(42)
print(random.sample(range(150), int(150*0.7)))
# Out:
# [28, 6, 70, 62, 57, 35, 26, 139, 22, 108, 8, 7, 23, 55, 59, 129, 148, 50, 107, 56, 114, 71, 1, 97, 103, 20, 89, 54, 43, 144, 19, 27, 126, 121, 13, 11, 48, 12, 45, 140, 44, 77, 33, 125, 5, 93, 58, 68, 15, 113, 10, 147, 37, 80, 79, 46, 73, 24, 90, 142, 105, 84, 29, 117, 99, 87, 112, 100, 120, 106, 94, 124, 47, 111, 143, 34, 9, 21, 102, 31, 78, 135, 82, 74, 149, 41, 138, 14, 52, 2, 51, 69, 25, 17, 4, 115, 36, 76, 96, 122, 64, 98, 145, 49, 88]

# %%
inds = random.sample(range(150), int(150*0.7))
inds[:5]
# Out:
# [36, 67, 35, 63, 143]

# %%
# iris 활용, 데이터 분리 실습

import seaborn as sns

# 훈련용 데이터 생성
iris = sns.load_dataset('iris')
iris[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris.loc[inds, :]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 36            5.5          3.5           1.3          0.2      setosa
# 67            5.8          2.7           4.1          1.0  versicolor
# 35            5.0          3.2           1.2          0.2      setosa
# 63            6.1          2.9           4.7          1.4  versicolor
# 143           6.8          3.2           5.9          2.3   virginica
# ..            ...          ...           ...          ...         ...
# 42            4.4          3.2           1.3          0.2      setosa
# 93            5.0          2.3           3.3          1.0  versicolor
# 135           7.7          3.0           6.1          2.3   virginica
# 133           6.3          2.8           5.1          1.5   virginica
# 84            5.4          3.0           4.5          1.5  versicolor
#
# [105 rows x 5 columns]

# %%
train_data = iris.loc[inds, :]

# %%
train_data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 36            5.5          3.5           1.3          0.2      setosa
# 67            5.8          2.7           4.1          1.0  versicolor
# 35            5.0          3.2           1.2          0.2      setosa
# 63            6.1          2.9           4.7          1.4  versicolor
# 143           6.8          3.2           5.9          2.3   virginica
# ..            ...          ...           ...          ...         ...
# 42            4.4          3.2           1.3          0.2      setosa
# 93            5.0          2.3           3.3          1.0  versicolor
# 135           7.7          3.0           6.1          2.3   virginica
# 133           6.3          2.8           5.1          1.5   virginica
# 84            5.4          3.0           4.5          1.5  versicolor
#
# [105 rows x 5 columns]

# %%
train_data.sort_index()
# 기본값(default) 오름차순
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 143           6.8          3.2           5.9          2.3  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
#
# [105 rows x 5 columns]

# %%
# train_data = train_data.sort_index()
train_data.sort_index(inplace = True)
# in place of ~ : ~을 대체하다, 대신하다

# %%
train_data.index
# Out:
# Int64Index([  0,   1,   2,   7,   8,  10,  12,  13,  14,  16,
#             ...
#             135, 136, 137, 140, 141, 143, 145, 146, 147, 148],
#            dtype='int64', length=105)

# %%
train_data.values
# Out:
# array([[5.1, 3.5, 1.4, 0.2, 'setosa'],
#        [4.9, 3.0, 1.4, 0.2, 'setosa'],
#        [4.7, 3.2, 1.3, 0.2, 'setosa'],
#        [5.0, 3.4, 1.5, 0.2, 'setosa'],
#        [4.4, 2.9, 1.4, 0.2, 'setosa'],
#        [5.4, 3.7, 1.5, 0.2, 'setosa'],
#        [4.8, 3.0, 1.4, 0.1, 'setosa'],
#        [4.3, 3.0, 1.1, 0.1, 'setosa'],
#        [5.8, 4.0, 1.2, 0.2, 'setosa'],
#        [5.4, 3.9, 1.3, 0.4, 'setosa'],
#        [5.1, 3.8, 1.5, 0.3, 'setosa'],
#        [5.4, 3.4, 1.7, 0.2, 'setosa'],
#        [5.1, 3.7, 1.5, 0.4, 'setosa'],
#        [4.6, 3.6, 1.0, 0.2, 'setosa'],
#        [5.1, 3.3, 1.7, 0.5, 'setosa'],
#        [5.0, 3.0, 1.6, 0.2, 'setosa'],
#        [5.2, 3.5, 1.5, 0.2, 'setosa'],
#        [5.2, 3.4, 1.4, 0.2, 'setosa'],
#        [4.8, 3.1, 1.6, 0.2, 'setosa'],
#        [5.2, 4.1, 1.5, 0.1, 'setosa'],
#        [5.5, 4.2, 1.4, 0.2, 'setosa'],
#        [4.9, 3.1, 1.5, 0.2, 'setosa'],
#        [5.0, 3.2, 1.2, 0.2, 'setosa'],
#        [5.5, 3.5, 1.3, 0.2, 'setosa'],
# ...

# %%
iris.loc[iris.index.isin(train_data.index)]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 7             5.0          3.4           1.5          0.2     setosa
# 8             4.4          2.9           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 143           6.8          3.2           5.9          2.3  virginica
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
#
# [105 rows x 5 columns]

# %%
iris.loc[~iris.index.isin(train_data.index)]
# isin() : 데이터 프레임/ Series가 데이터를 포함하고 있는지를 알려줌(T/F)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 3             4.6          3.1           1.5          0.2      setosa
# 4             5.0          3.6           1.4          0.2      setosa
# 5             5.4          3.9           1.7          0.4      setosa
# 6             4.6          3.4           1.4          0.3      setosa
# 9             4.9          3.1           1.5          0.1      setosa
# 11            4.8          3.4           1.6          0.2      setosa
# 15            5.7          4.4           1.5          0.4      setosa
# 17            5.1          3.5           1.4          0.3      setosa
# 18            5.7          3.8           1.7          0.3      setosa
# 24            4.8          3.4           1.9          0.2      setosa
# 26            5.0          3.4           1.6          0.4      setosa
# 29            4.7          3.2           1.6          0.2      setosa
# ...

# %%
test_data = iris.loc[iris.index.isin(train_data.index)]
test_data[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa

# %%
train_data[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 7           5.0          3.4           1.5          0.2  setosa
# 8           4.4          2.9           1.4          0.2  setosa

# %%
test_data.sort_index(inplace = True)

# %%
iris[:]
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris.sample(frac = 0.7)
# frac : fraction
# Out:
#      sepal_length  sepal_width  petal_length  petal_width     species
# 98            5.1          2.5           3.0          1.1  versicolor
# 13            4.3          3.0           1.1          0.1      setosa
# 129           7.2          3.0           5.8          1.6   virginica
# 115           6.4          3.2           5.3          2.3   virginica
# 47            4.6          3.2           1.4          0.2      setosa
# ..            ...          ...           ...          ...         ...
# 8             4.4          2.9           1.4          0.2      setosa
# 97            6.2          2.9           4.3          1.3  versicolor
# 29            4.7          3.2           1.6          0.2      setosa
# 31            5.4          3.4           1.5          0.4      setosa
# 119           6.0          2.2           5.0          1.5   virginica
#
# [105 rows x 5 columns]

# %%
train_data = iris.sample(frac = 0.7)
test_data = iris.loc[~iris.index.isin(train_data.index)]

# %%
train_data.shape, test_data.shape
# Out:
# ((105, 5), (45, 5))

# %%
# 데이터 셋 분리 (train data / test data)

import seaborn as sns

iris = sns.load_dataset('iris')

# %%
iris[:5]
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# x, y 분리(특성, 라벨)

x = iris.iloc[:, :-1]
y = iris.iloc[:, -1]

# %%
x, y
# Out:
# (     sepal_length  sepal_width  petal_length  petal_width
#  0             5.1          3.5           1.4          0.2
#  1             4.9          3.0           1.4          0.2
#  2             4.7          3.2           1.3          0.2
#  3             4.6          3.1           1.5          0.2
#  4             5.0          3.6           1.4          0.2
#  ..            ...          ...           ...          ...
#  145           6.7          3.0           5.2          2.3
#  146           6.3          2.5           5.0          1.9
#  147           6.5          3.0           5.2          2.0
#  148           6.2          3.4           5.4          2.3
#  149           5.9          3.0           5.1          1.8
#
#  [150 rows x 4 columns],
#  0         setosa
#  1         setosa
#  2         setosa
#  3         setosa
#  4         setosa
#           ...
#  145    virginica
#  146    virginica
#  147    virginica
#  148    virginica
#  149    virginica
# ...

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state=42)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((105, 4), (45, 4), (105,), (45,))

# %%
y_test.value_counts()
# Out:
# setosa        19
# versicolor    13
# virginica     13
# Name: species, dtype: int64
